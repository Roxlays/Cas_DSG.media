# %% [markdown]
# # Scraping DCG.media

# %%
### SCRAPING
import requests as rq
from bs4 import BeautifulSoup

### DATABASES
import pandas as pd
import numpy as np
from ydata_profiling import ProfileReport

### VISUALISATION
import plotly.express as px

### DIVERS
from tqdm.notebook import tqdm

### FORMAT
from datetime import datetime, timezone
import time
import json

# %% [markdown]
# ## Définition des variables

# %%
website = 'invistita'
abbr = 'iia'
tld = '.fr'

# %%
page_number = 1
top_url = f'https://www.{website+tld}'
top_search_url = f'{top_url}/page/{page_number}/?s'

# %% [markdown]
# ## Définition des fonctions

# %% [markdown]
# ### Obtenir le nombre de pages de résultats de recherche

# %%
def get_max_page_results(top_search_url):
    r = rq.get(top_search_url)
    soup = BeautifulSoup(r.content)
    page_numbers = soup.find_all("a", class_="page-numbers")
    pages = [int(page.text) for page in page_numbers if page.text.isdigit()]
    if pages:
        return max(pages)  # Le numéro le plus élevé correspond au total de pages
    return 1
get_max_page_results(top_search_url)
# Out:
# 15

# %% [markdown]
# ### Obtenir la liste des pages de résultats de recherche

# %%
def get_all_results_pages(page_final):
    urls = []
    for i in range(page_final):
        i = f'{top_url}/page/{i+1}/?s'
        urls.append(i)
    return urls
get_all_results_pages(get_max_page_results(top_search_url))
# Out:
# ['https://www.invistita.fr/page/1/?s',
#  'https://www.invistita.fr/page/2/?s',
#  'https://www.invistita.fr/page/3/?s',
#  'https://www.invistita.fr/page/4/?s',
#  'https://www.invistita.fr/page/5/?s',
#  'https://www.invistita.fr/page/6/?s',
#  'https://www.invistita.fr/page/7/?s',
#  'https://www.invistita.fr/page/8/?s',
#  'https://www.invistita.fr/page/9/?s',
#  'https://www.invistita.fr/page/10/?s',
#  'https://www.invistita.fr/page/11/?s',
#  'https://www.invistita.fr/page/12/?s',
#  'https://www.invistita.fr/page/13/?s',
#  'https://www.invistita.fr/page/14/?s',
#  'https://www.invistita.fr/page/15/?s']

# %% [markdown]
# ### Obtenir tous les liens des articles sur une page de recherche

# %%
def get_articles_on_page(search_results):
    urls_articles = []
    s = rq.Session()
    for p in tqdm(search_results):
        r = s.get(p)
        soup = BeautifulSoup(r.content)
        articles = soup.find_all('h2', class_ = 'title')
        for article in articles:
            url = article.find('a', href=True)['href']
            urls_articles.append(url)
    return urls_articles

# %%
get_articles_on_page(get_all_results_pages(get_max_page_results(top_search_url)))
# Out:
#   0%|          | 0/15 [00:00<?, ?it/s]
# ['https://www.invistita.fr/les-cles-dune-gestion-patrimoniale-reussie-3-bonnes-raisons-de-faire-appel-a-un-expert/',
#  'https://www.invistita.fr/frais-de-notaire-pour-donation-astuces-pour-reduire-les-couts/',
#  'https://www.invistita.fr/cadessavoies-tout-savoir-sur-la-gestion-des-demarches-administratives/',
#  'https://www.invistita.fr/www-lefil-loutil-incontournable-pour-les-clients-du-credit-agricole-pyrenees-gascogne/',
#  'https://www.invistita.fr/crca22-acceder-a-vos-comptes-credit-agricole-en-ligne-facilement/',
#  'https://www.invistita.fr/comment-cmut-direct-pro-revolutionne-la-gestion-bancaire-des-entrepreneurs/',
#  'https://www.invistita.fr/comment-optimiser-lutilisation-de-le-carte-bleue-nomade-de-la-banque-postale/',
#  'https://www.invistita.fr/les-etapes-essentielles-pour-www-ca-cmds-fr-acceder-a-mes-comptes/',
#  'https://www.invistita.fr/pourquoi-la-prop-firm-nova-funding-a-autant-de-succes-chez-les-traders-debutants/',
#  'https://www.invistita.fr/guide-complet-des-codes-postaux-du-quebec-tout-ce-que-vous-devez-savoir/',
#  'https://www.invistita.fr/www-monportailsecuritas-fr-accedez-a-votre-espace-securise/',
#  'https://www.invistita.fr/prelevement-asp-explique-comprendre-son-importance-en-sante/',
#  'https://www.invistita.fr/cacentrest-connexion-au-compte/',
#  'https://www.invistita.fr/comment-se-connecter-a-hello-bank/',
comment-ouvrir-un-compte-bancaire-pro/',
#  'https://www.invistita.fr/comment-trouver-et-concretiser-une-bonne-idee-dentreprise/',
#  'https://www.invistita.fr/traduction-financiere-quelques-conseils-pour-bien-traduire-vos-documents/',
#  'https://www.invistita.fr/des-informations-precises-sur-la-fiscalite-en-israel/',
#  'https://www.invistita.fr/les-erreurs-a-eviter-avec-son-credit-autorise/',
#  'https://www.invistita.fr/faire-vos-premiers-pas-en-bourse/',
#  'https://www.invistita.fr/ce-quil-faut-savoir-si-vous-souhaitez-entreprendre-a-dubai/',
#  'https://www.invistita.fr/comment-investir-dans-la-crypto/',
#  'https://www.invistita.fr/comment-avoir-une-vue-densemble-sur-votre-patrimoine/',
#  'https://www.invistita.fr/btp-faut-il-de-lexperience-pour-etre-assure/',
#  'https://www.invistita.fr/que-devez-vous-savoir-pour-bien-valoriser-votre-actif-immobilier/',
#  'https://www.invistita.fr/pourquoi-utiliser-un-comparateur-dassurances-en-ligne/',
#  'https://www.invistita.fr/quelles-sont-les-conditions-pour-se-faire-racheter-un-credit/',
#  'https://www.invistita.fr/ouvrir-sa-societe-les-choses-a-savoir/',
#  'https://www.invistita.fr/un-rachat-or-ancien-pour-fabriquer-de-nouvelles-pieces-de-joaillerie/',
#  'https://www.invistita.fr/comment-choisir-votre-avocat-en-droit-de-la-construction/',
#  'https://www.invistita.fr/pourquoi-recourir-a-un-cabinet-de-gestion-de-patrimoine/',
#  'https://www.invistita.fr/quest-ce-que-le-marketing-emotionnel/',
#  'https://www.invistita.fr/les-avantages-de-se-procurer-une-assurance-en-ligne/',
#  'https://www.invistita.fr/quelle-est-la-meilleure-banque-en-ligne/',
#  'https://www.invistita.fr/quelle-est-la-valeur-du-bitcoin/',
#  'https://www.invistita.fr/ou-acheter-du-bitcoin-cash/',
#  'https://www.invistita.fr/quelle-banque-en-ligne-choisir/',
#  'https://www.invistita.fr/quel-est-le-montant-minimum-pour-trader/',
#  'https://www.invistita.fr/6-criteres-pour-comparer-les-rc-pro/',
#  'https://www.invistita.fr/4-elements-a-comparer-pour-mieux-gerer-votre-budget/',
#  'https://www.invistita.fr/quest-ce-quune-condition-suspensive-lors-dun-achat-immobilier/',
#  'https://www.invistita.fr/fonds-et-placements-speciaux-quelle-option-choisir-en-2022/',
#  'https://www.invistita.fr/trading-quelle-plateforme-pour-un-debutant/',
#  'https://www.invistita.fr/pourquoi-utiliser-une-carte-de-paiement-professionnelle/',
#  'https://www.invistita.fr/est-il-moins-cher-de-louer-ou-dacheter-une-maison/',
#  'https://www.invistita.fr/les-solutions-pour-economiser-de-largent-sur-ses-achats-en-ligne/',
#  'https://www.invistita.fr/assurance-auto-le-point-sur-le-systeme-bonus-malus/',
#  'https://www.invistita.fr/preparez-sereinement-votre-avenir-avec-un-contrat-dassurance-vie-sur-mesure/',
#  'https://www.invistita.fr/ouvrir-son-compte-chez-boursorama-banque-pourquoi-est-ce-recommande/',
#  'https://www.invistita.fr/les-cryptomonnaies-prometteuses-qui-veulent-concurrencer-le-bitcoin/',
#  'https://www.invistita.fr/souscrire-a-une-assurance-vie-au-luxembourg/',
#  'https://www.invistita.fr/nos-conseils-dinvestissement-pour-2022/',
#  'https://www.invistita.fr/3-avantages-douvrir-un-compte-offshore-a-hong-kong/',
#  'https://www.invistita.fr/comment-choisir-un-lecteur-de-carte-bancaire/',
#  'https://www.invistita.fr/les-cles-dune-gestion-patrimoniale-reussie-3-bonnes-raisons-de-faire-appel-a-un-expert/',
#  'https://www.invistita.fr/frais-de-notaire-pour-donation-astuces-pour-reduire-les-couts/',
#  'https://www.invistita.fr/cadessavoies-tout-savoir-sur-la-gestion-des-demarches-administratives/',
#  'https://www.invistita.fr/www-lefil-loutil-incontournable-pour-les-clients-du-credit-agricole-pyrenees-gascogne/',
#  'https://www.invistita.fr/crca22-acceder-a-vos-comptes-credit-agricole-en-ligne-facilement/',
#  'https://www.invistita.fr
#  'https://www.invistita.fr/bitcoin-ce-quil-faut-savoir-sur-cette-monnaie-virtuelle/',
#  'https://www.invistita.fr/avez-vous-interet-a-atteindre-le-plafond-du-pel/',
#  'https://www.invistita.fr/comment-lintelligence-artificielle-est-elle-en-train-de-revolutionner-lassurance/',
#  'https://www.invistita.fr/il-est-temps-de-confier-vos-besoins-en-traduction-a-un-prestataire-de-services-de-traduction-professionnel/',
#  'https://www.invistita.fr/pourquoi-gerer-son-stress-pour-ameliorer-ses-presentations-en-entreprise/',
#  'https://www.invistita.fr/simplanter-dans-le-pays-daix/',
#  'https://www.invistita.fr/comment-faire-de-la-location-de-studio-a-rennes/',
#  'https://www.invistita.fr/taxe-dapprentissage-impositions-exoneration-on-vous-dit-tout/',
#  'https://www.invistita.fr/financez-facilement-vos-petits-projets-de-vie/',
#  'https://www.invistita.fr/quest-ce-quun-programme-loi-pinel/',
#  'https://www.invistita.fr/comment-la-finance-comportementale-peut-faire-de-vous-un-meilleur-investisseur/',
#  'https://www.invistita.fr/comment-evaluer-son-taux-dendettement/',
#  'https://www.invistita.fr/comment-garantir-une-meilleure-croissance-a-son-entreprise/',
#  'https://www.invistita.fr/devenir-trader-grace-a-des-formations-cest-tout-a-fait-possible/',
#  'https://www.invistita.fr/comment-choisir-son-logiciel-de-gestion-de-tresorerie/',
#  'https://www.invistita.fr/la-methode-du-lean-management/',
#  'https://www.invistita.fr/les-cles-dune-gestion-patrimoniale-reussie-3-bonnes-raisons-de-faire-appel-a-un-expert/',
#  'https://www.invistita.fr/frais-de-notaire-pour-donation-astuces-pour-reduire-les-couts/',
#  'https://www.invistita.fr/cadessavoies-tout-savoir-sur-la-gestion-des-demarches-administratives/',
#  'https://www.invistita.fr/www-lefil-loutil-incontournable-pour-les-clients-du-credit-agricole-pyrenees-gascogne/',
#  'https://www.invistita.fr/crca22-acceder-a-vos-comptes-credit-agricole-en-ligne-facilement/',
#  'https://www.invistita.fr/que-faut-il-savoir-pour-creer-et-gerer-efficacement-sa-pme/',
#  'https://www.invistita.fr/comment-eduquer-financierement-vos-enfants/',
#  'https://www.invistita.fr/pourquoi-faire-appel-a-un-courtier-pour-votre-credit-a-la-consommation/',
#  'https://www.invistita.fr/logement-neuf-la-penurie-doffres-pousse-les-francais-a-se-surendetter/',
#  'https://www.invistita.fr/pourquoi-proposer-une-solution-de-paiement-omnicanal/',
#  'https://www.invistita.fr/pea-ou-compte-titre-que-choisir-pour-investir/',
#  'https://www.invistita.fr/quel-site-investir/',
#  'https://www.invistita.fr/top-des-pays-europeens-qui-paient-le-moins-dimpots/',
#  'https://www.invistita.fr/logiciel-de-facturation-est-il-obligatoire-ou-non/',
#  'https://www.invistita.fr/savez-vous-tout-a-propos-de-limpot-sur-le-revenu/',
#  'https://www.invistita.fr/pourquoi-les-promoteurs-sinteressent-ils-de-plus-en-plus-a-la-creation-de-societe-offshore/',
#  'https://www.invistita.fr/quelles-aides-sociales-pour-les-retraites/',
#  'https://www.invistita.fr/comment-investir-dans-limmobilier-en-partant-de-rien/',
#  'https://www.invistita.fr/comment-acheter-des-fonds-dinvestissement/',
#  'https://www.invistita.fr/cest-quoi-la-difference-entre-la-comptabilite-generale-et-la-comptabilite-de-gestion/',
#  'https://www.invistita.fr/quels-actions-acheter-en-2020/',
#  'https://www.invistita.fr/qui-est-le-concurrent-de-paypal/',
#  'https://www.invistita.fr/quest-ce-que-wiseed/',
#  'https://www.invistita.fr/comment-miner-du-stellar/',
#  'https://www.invistita.fr/quelle-banque-pour-une-eurl/',
#  'https://www.invistita.fr/quels-indicateurs-pour-le-day-trading/',
#  'https://www.invistita.fr/comment-faire-un-chiffre-daffaire-previsionnel/',
#  'https://www.invistita.fr/comment-gagner-de-largent-avec-les-etf/',
#  'https://www.invistita.fr/quelle-culture-agricole-est-la-plus-rentable-en-cote-divoire/',
#  'https://www.invistita.fr/comment-alimenter-mon-compte-ma-french-bank/',
#  'https://www.invistita.fr/quest-ce-quun-accident-scolaire/',
#  'https://www.invistita.fr/comment-faire-de-largent-avec-100-000-euros/',
#  'https://www.invistita.fr/comment-optimiser-lobtention-de-son-dscg/',
#  'https://www.invistita.fr/comment-sy-prendre-pour-contacter-gratuitement-le-service-client-dune-entreprise/',
#  'https://www.invistita.fr/differences-entre-cheque-certifie-et-cheque-vise/',
#  'https://www.invistita.fr/montant-du-smic-2020-net-et-brut/',
#  'https://www.invistita.fr/comment-reussir-son-demenagement-dentreprise/',
#  'https://www.invistita.fr/trouver-une-banque-pres-de-chez-moi-comment-faire/',
#  'https://www.invistita.fr/prelevement-spb-quest-ce-que-cest-2/',
#  'https://www.invistita.fr/peut-on-recevoir-un-virement-dans-la-nuit/',
#  'https://www.invistita.fr/le-bitcoin-en-route-vers-ses-plus-hauts-historiques/',
#  'https://www.invistita.fr/volatilite-cryptomonnaies-pourquoi-et-comment-en-profiter/',
#  'https://www.invistita.fr/bitcoin-quel-prix-pour-la-periode-apres-le-hud/',
#  'https://www.invistita.fr/blackrock-bitcoin-vaut-mieux-que-lor/',
#  'https://www.invistita.fr/comment-consulter-mon-compte-bancaire-au-credit-agricole/',
#  'https://www.invistita.fr/combien-de-temps-pour-un-virement-bancaire/',
#  'https://www.invistita.fr/libelle-de-compte-definition/',
#  'https://www.invistita.fr/certicode-et-certicode-plus-de-la-banque-postale/',
#  'https://www.invistita.fr/le-service-filbanque-du-cic-principe-et-tarifs/',
#  'https://www.invistita.fr/prelevement-crcam-a-quoi-cela-correspond/',
#  'https://www.invistita.fr/certicode-plus-a-la-banque-postale-pour-des-transactions-securisees/',
#  'https://www.invistita.fr/lepargne-des-francais-a-bondi-en-2020/',
#  'https://www.invistita.fr/quel-est-le-parcours-dachat-dun-bien-immobilier/',
#  'https://www.invistita.fr/pret-immobilier-pourquoi-comparer-les-assurances-emprunteurs/',
#  'https://www.invistita.fr/3-avantages-a-miser-sur-une-plateforme-pour-trouver-un-comptable/',
#  'https://www.invistita.fr/les-cles-dune-gestion-patrimoniale-reussie-3-bonnes-raisons-de-faire-appel-a-un-expert/',
#  'https://www.invistita.fr/frais-de-notaire-pour-donation-astuces-pour-reduire-les-couts/',
#  'https://www.invistita.fr/cadessavoies-tout-savoir-sur-la-gestion-des-demarches-administratives/',
#  'https://www.invistita.fr/www-lefil-loutil-incontournable-pour-les-clients-du-credit-agricole-pyrenees-gascogne/',
#  'https://www.invistita.fr/crca22-acceder-a-vos-comptes-credit-agricole-en-ligne-facilement/',
#  'https://www.invistita.fr/le-rachat-de-credit-un-outil-indispensable-pour-votre-quotidien/',
#  'https://www.invistita.fr/un-pret-personnel-peut-vous-aider-a-realiser-un-projet/',
#  'https://www.invistita.fr/impayes-les-bonnes-raisons-de-passer-par-un-recouvrement-de-creances/',
#  'https://www.invistita.fr/pourquoi-realiser-un-rachat-de-credit/',
#  'https://www.invistita.fr/comment-obtenir-son-pret-personnel-au-meilleur-taux/',
#  'https://www.invistita.fr/comment-bien-choisir-sa-scpi/',
#  'https://www.invistita.fr/preparez-votre-retraite-plus-sereinement-avec-le-3e-pilier/',
#  'https://www.invistita.fr/comment-obtenir-un-pret-immobilier-au-luxembourg/',
#  'https://www.invistita.fr/comment-economiser-de-largent-pour-le-voyage-de-vos-reves-en-tant-quetudiant/',
#  'https://www.invistita.fr/quelles-erreurs-eviter-avant-de-demander-un-pret-immobilier/',
#  'https://www.invistita.fr/comment-se-proteger-contre-le-gazumping/',
#  'https://www.invistita.fr/comment-aider-vos-enfants-a-acquerir-un-bien-immobilier/',
#  'https://www.invistita.fr/pret-pour-investissement-locatif-quelles-sont-les-meilleures-options/',
#  'https://www.invistita.fr/comment-garder-de-bonnes-relations-de-voisinage-lors-dune-renovation/',
#  'https://www.invistita.fr/financement-de-demarrage-dune-entreprise-par-les-amis-et-la-famille-est-ce-une-bonne-idee/',
#  'https://www.invistita.fr/faut-il-recourir-aux-services-dun-agent-immobilier-pour-lachat-dune-maison/',
#  'https://www.invistita.fr/les-cles-dune-gestion-patrimoniale-reussie-3-bonnes-raisons-de-faire-appel-a-un-expert/',
#  'https://www.invistita.fr/frais-de-notaire-pour-donation-astuces-pour-reduire-les-couts/',
#  'https://www.invistita.fr/cadessavoies-tout-savoir-sur-la-gestion-des-demarches-administratives/',
#  'https://www.invistita.fr/www-lefil-loutil-incontournable-pour-les-clients-du-credit-agricole-pyrenees-gascogne/',
#  'https://www.invistita.fr/crca22-acceder-a-vos-comptes-credit-agricole-en-ligne-facilement/']

# %% [markdown]
# ### Récupérer les infos qu'on souhaite sur chaque article

# %%
def get_article_info(r, url_article):
    # Liste de variables
    noms_variables = [
        'url',  # URL scrapée
        'canonical_url', 'slug', 'meta_title', 'meta_desc',  # Infos issues de la balise meta
        'date_published', 'date_modified',  # Infos dates
        'author',  # Parfois en meta
        'title', 'category', 'views', 'reading_time',  # Metadonnées contenues ailleurs que dans la balise meta
        'content', 'raw_content'  # Contenu de la page
    ]
    
    # Initialisation du dictionnaire
    data = {nom: np.nan for nom in noms_variables}
    
    data['url'] = url_article
    
    soup = BeautifulSoup(r.content, 'lxml')
    
    try:
        data['canonical_url'] = soup.find('link', {'rel': 'canonical'})['href']
    except:
        pass
    
    try:
        data['slug'] = data['canonical_url'].split('/')[-2] if data['canonical_url'] else np.nan
    except:
        pass

    try:
        data['meta_title'] = soup.find('meta', {'property': 'og:title'})['content']
    except:
        pass

    try:
        data['meta_desc'] = soup.find('meta', {'property': 'og:description'})['content']
    except:
        pass

    try:
        data['date_published'] = pd.to_datetime(soup.find('meta', {'property': 'article:published_time'})['content'][:-6], utc=True)
    except:
        pass

    try:
        data['date_modified'] = pd.to_datetime(soup.find('meta', {'property': 'article:modified_time'})['content'][:-6], utc=True)
    except:
        pass

    try:
        data['author'] = soup.find("meta", {'name': 'author'})['content']
    except:
        try:
            data['author'] = soup.find(class_="author").text.split('Publié par ')[-1]
        except:
            pass

    try:
        data['title'] = soup.find('h1').text
    except:
        pass

    try:
        data['category'] = ", ".join([link.text.strip() for link in soup.find("div", class_="post-category").find_all("a")])
    except:
        pass

    try:
        data['views'] = int(soup.find('div', class_='views').text)
    except:
        pass

    try:
        data['reading_time'] = int(soup.find('meta', {'name': 'twitter:data2'})['content'].split(' ')[0]) if soup.find('meta', {'name': 'twitter:data2'}) and 'minutes' in soup.find('meta', {'name': 'twitter:data2'})['content'] else np.nan
    except:
        pass

    try:
        data['content'] = BeautifulSoup(str(soup.find("article")), 'lxml').get_text()
    except:
        pass

    try:
        data['raw_content'] = str(soup.find("article"))
    except:
        pass

    # Ajout de features
    data['length'] = len(str(data['content']).split())
    
    if pd.notnull(data['date_published']):
        data['days_since_published'] = int((pd.Timestamp.now(tz='UTC') - data['date_published']).days)
    else:
        data['days_since_published'] = np.nan
    
    # Création de la série
    series = pd.Series(data)
    series.name = url_article
    
    # Ajout de features supplémentaires
    if pd.notnull(data.get('views')) and pd.notnull(data.get('days_since_published')):
        series['views_daily'] = series['views'] / (series['days_since_published'] + 1)
        series['views_monthly'] = series['views_daily'] * 30
    else:
        series['views_daily'] = np.nan
        series['views_monthly'] = np.nan
    
    series['website'] = top_url
    
    return series

# %% [markdown]
# ## Fonction finale

# %%
article_list = get_articles_on_page(get_all_results_pages(get_max_page_results(top_search_url)))
# Out:
#   0%|          | 0/15 [00:00<?, ?it/s]

# %% [markdown]
# ### Fonction finale

# %%
# Import des packages
from concurrent.futures import ThreadPoolExecutor, as_completed
import time

# Initialisation du compteur
start_time = time.time()

# Fonction principale qui sauvegarde le DataFrame dans un fichier CSV et le retourne
def scrape_all_articles(urls, batch_size=250, max_workers=20):
    # Initialisation d'une session réutilisable
    session = rq.Session()

    # Création d'une fonction qui traite chaque URL
    def process_url(url):
            try:
                r = session.get(url)
                return get_article_info(r, url)
            except Exception as e:
                print(f"Erreur pour {url}: {str(e)}")
                return pd.Series(name=url)

    # Utilise ThreadPoolExecutor pour paralléliser le traitement
    results = []
    with ThreadPoolExecutor(max_workers=max_workers) as executor:
        # Parcourt la liste d'URLs par lots de taille 'batch_size'
        for i in range(0, len(urls), batch_size):
            # Extrait un lot d'URLs
            batch = urls[i:i+batch_size]
            # Crée et soumet des tâches pour chaque URL du lot
            futures = [executor.submit(process_url, url) for url in batch]
            
            # Traite les résultats au fur et à mesure qu'ils sont terminés
            for future in tqdm(as_completed(futures), total=len(batch), desc=f"Batch {i//batch_size + 1} / {len(urls)//batch_size+1}"):
                # Récupère le résultat de la tâche
                result = future.result()
                # Si le résultat n'est pas None (pas d'erreur), l'ajoute aux résultats
                if result is not None:
                    results.append(result)
    
    # Création du DataFrame final
    df_final = pd.DataFrame(results)
    
    # Ajout de colonnes calculées
    df_final['website'] = top_url
    df_final['scraping_date'] = pd.Timestamp.now(tz='UTC')

    df_final.columns = ['article_url', 'article_canonical_url', 'article_slug',
       'article_meta_title', 'article_meta_desc', 'article_date_published',
       'article_date_modified', 'article_author', 'article_title',
       'article_category', 'article_views', 'article_reading_time',
       'article_content', 'article_raw_content', 'article_length',
       'days_since_published', 'article_views_daily', 'article_views_monthly',
       'website', 'scraping_date']

    # Sauvegarde en CSV
    df_final.to_csv(f'scraping_{abbr}.csv', sep='|', index=True)
    print(f"Scraping terminé. Total d'articles : {len(df_final)}")
    return df_final

df = scrape_all_articles(article_list)

end_time = time.time()
print(end_time - start_time)
# Out:
# Batch 1 / 4:   0%|          | 0/250 [00:00<?, ?it/s]
# Batch 2 / 4:   0%|          | 0/250 [00:00<?, ?it/s]
# Batch 3 / 4:   0%|          | 0/250 [00:00<?, ?it/s]
# Batch 4 / 4:   0%|          | 0/41 [00:00<?, ?it/s]
# Scraping terminé. Total d'articles : 791
# 70.49676322937012

# %%
# Création d'un rapport de profil avec pandas_profiling
profile = ProfileReport(df, title=f"{abbr.title()} Scraping Report", explorative=True)

# Génération du rapport au format HTML
profile.to_file(f"scraping_report_{abbr}.html")
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# c:\Users\enzol\anaconda3\Lib\site-packages\ydata_profiling\model\correlations.py:66: UserWarning: There was an attempt to calculate the auto correlation, but this failed.
# To hide this warning, disable the calculation
# (using `df.profile_report(correlations={"auto": {"calculate": False}})`
# If this is problematic for your use case, please report this as an issue:
# https://github.com/ydataai/ydata-profiling/issues
# (include the error message: 'cannot reindex on an axis with duplicate labels')
#   warnings.warn(
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
