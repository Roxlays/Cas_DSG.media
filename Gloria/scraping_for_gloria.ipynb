# %% [markdown]
# # Scraping DCG.media

# %%
### SCRAPING
import requests as rq
from bs4 import BeautifulSoup

### DATABASES
import pandas as pd
import numpy as np
from ydata_profiling import ProfileReport

### VISUALISATION
import plotly.express as px

### DIVERS
from tqdm.notebook import tqdm

### FORMAT
from datetime import datetime, timezone
import time
import json

# %% [markdown]
# ## Définition des variables

# %%
website = 'mybeautifuljob'
abbr = 'mbj'
tld = '.com'

# %%
page_number = 1
top_url = f'https://www.{website+tld}'
top_search_url = f'{top_url}/page/{page_number}/?s'

# %% [markdown]
# ## Définition des fonctions

# %% [markdown]
# ### Obtenir le nombre de pages de résultats de recherche

# %%
def get_max_page_results(top_search_url):
    r = rq.get(top_search_url)
    soup = BeautifulSoup(r.content)
    page_numbers = soup.find_all("a", class_="page-numbers")
    pages = [int(page.text) for page in page_numbers if page.text.isdigit()]
    if pages:
        return max(pages)  # Le numéro le plus élevé correspond au total de pages
    return 1
get_max_page_results(top_search_url)
# Out:
# 8

# %% [markdown]
# ### Obtenir la liste des pages de résultats de recherche

# %%
def get_all_results_pages(page_final):
    urls = []
    for i in range(page_final):
        i = f'{top_url}/page/{i+1}/?s'
        urls.append(i)
    return urls
get_all_results_pages(get_max_page_results(top_search_url))
# Out:
# ['https://www.mybeautifuljob.com/page/1/?s',
#  'https://www.mybeautifuljob.com/page/2/?s',
#  'https://www.mybeautifuljob.com/page/3/?s',
#  'https://www.mybeautifuljob.com/page/4/?s',
#  'https://www.mybeautifuljob.com/page/5/?s',
#  'https://www.mybeautifuljob.com/page/6/?s',
#  'https://www.mybeautifuljob.com/page/7/?s',
#  'https://www.mybeautifuljob.com/page/8/?s']

# %% [markdown]
# ### Obtenir tous les liens des articles sur une page de recherche

# %%
def get_articles_on_page(search_results):
    urls_articles = []
    s = rq.Session()
    for p in tqdm(search_results):
        r = s.get(p)
        soup = BeautifulSoup(r.content)
        articles = soup.find_all('h2', class_ = 'title')
        for article in articles:
            url = article.find('a', href=True)['href']
            urls_articles.append(url)
    return urls_articles

# %%
get_articles_on_page(get_all_results_pages(get_max_page_results(top_search_url)))
# Out:
#   0%|          | 0/8 [00:00<?, ?it/s]
# ['https://www.mybeautifuljob.com/developper-ses-competences-pour-acceder-a-de-nouvelles-opportunites-sur-le-marche-du-travail-a-strasbourg/',
#  'https://www.mybeautifuljob.com/lms-unice-astuces-pour-une-utilisation-optimale/',
#  'https://www.mybeautifuljob.com/ages-bts-quels-sont-les-membres-les-plus-jeunes/',
#  'https://www.mybeautifuljob.com/limportance-cruciale-dun-tableau-des-metres-cubes-pour-evaluer-vos-volumes/',
#  'https://www.mybeautifuljob.com/comprendre-le-prix-de-lessec-frais-de-scolarite-et-investissements/',
#  'https://www.mybeautifuljob.com/nero-educ-plateforme-de-formation/',
#  'https://www.mybeautifuljob.com/messagerie-academique-de-lyon-guide-exhaustif-pour-les-nouveaux-utilisateurs/',
#  'https://www.mybeautifuljob.com/salaire-de-testeur-de-toboggans-une-retribution-ludique-mais-lucrative/',
#  'https://www.mybeautifuljob.com/comment-mycampus-eduservices-transforme-la-gestion-de-votre-parcours-educatif/',
#  'https://www.mybeautifuljob.com/accedez-a-votre-messagerie-academique-nancy-metz-guide-detaille/',
#  'https://www.mybeautifuljob.com/ediflex-plateforme-educative-pour-un-apprentissage-flexible/',
#  'https://www.mybeautifuljob.com/ma-classe-en-auvergne-plateforme-educative-regionale/',
#  'https://www.mybeautifuljob.com/prix-formation-125-cout-et-details-pour-conduire-un-scooter-ou-moto-legere/',
#  'https://www.mybeautifuljob.com/les-metiers-en-vogue-explorer-les-secteurs-porteurs-pour-une-reconversion-professionnelle/',
#  'https://www.mybeautifuljob.com/langlais-au-travail-un-atout-non-negligeable/',
#  'https://www.mybeautifuljob.com/quel-est-le-niveau-detudes-requis-pour-etre-cadre/',
#  'https://www.mybeautifuljob.com/webmail-creteil-connexion-a-lespace-messagerie/',
#  'https://www.mybeautifuljob.com/delai-de-prevenance-comment-le-calculer/',
#  'https://www.mybeautifuljob.com/comment-etre-pro-actif-au-travail/',
#  'https://www.mybeautifuljob.com/comment-se-mettre-a-son-compte-sans-diplome/',
#  'https://www.mybeautifuljob.com/comment-optimiser-sa-formation-pour-travailler-le-week-end/',
#  'https://www.mybeautifuljob.com/explorer-linspiration-les-meilleures-citations-sur-les-ressources-humaines/',
#  'https://www.mybeautifuljob.com/pourquoi-le-drp-est-crucial-pour-une-strategie-rh-aboutie/',
#  'https://www.mybeautifuljob.com/saisir-les-meilleures-opportunites-comment-denicher-une-offre-demploi-en-dordogne/',
#  'https://www.mybeautifuljob.com/comment-etre-sur-de-trouver-un-emploi-dans-les-plus-brefs-delais/',
#  'https://www.mybeautifuljob.com/les-fonctionnalites-meconnues-diprof-lille-a-decouvrir/',
#  'https://www.mybeautifuljob.com/zoom-sur-le-salaire-dun-chauffeur-de-bus-a-la-ratp-chiffres-et-perspectives/',
#  'https://www.mybeautifuljob.com/comment-la-mission-locale-de-bressuire-accompagne-les-jeunes-vers-lemploi/',
#  'https://www.mybeautifuljob.com/zoom-sur-le-salaire-du-pharmacien-dans-lindustrie-facteurs-cles-et-perspectives/',
#  'https://www.mybeautifuljob.com/declinaisons-allemandes-astuces-pour-ne-plus-se-meprendre/',
#  'https://www.mybeautifuljob.com/conseils-pour-reussir-votre-code-de-la-route-du-premier-coup/',
#  'https://www.mybeautifuljob.com/les-etapes-cardinales-pour-une-fiche-de-suivi-irreprochable-dun-projet-detudes-superieures/',
#  'https://www.mybeautifuljob.com/conseils-infaillibles-pour-rediger-une-lettre-de-motivation-percutante-pour-un-cap-coiffure/',
#  'https://www.mybeautifuljob.com/cv-australien-efficace-conseils-et-exemple-pour-reussir/',
#  'https://www.mybeautifuljob.com/comprendre-la-methode-nerac-avantages-et-fonctionnement-efficace/',
#  'https://www.mybeautifuljob.com/in-concreto-vs-in-abstracto-comprendre-les-differences-essentielles/',
#  'https://www.mybeautifuljob.com/aesh-avantages-et-defis-pour-laccompagnement-deleves-handicapes/',
#  'https://www.mybeautifuljob.com/refus-de-financement-par-pole-emploi-comprendre-les-raisons-et-agir/',
#  'https://www.mybeautifuljob.com/reconversion-en-kinesitherapie-etapes-et-conseils-pour-changer-de-carriere-efficacement/',
#  'https://www.mybeautifuljob.com/titre-professionnel-installateur-thermique-et-sanitaire-tp-its-decouvrez-les-perspectives-de-carriere-dans-le-domaine-de-lenergie-et-du-confort/',
#  'https://www.mybeautifuljob.com/protegez-vos-employes-avec-le-dispositif-homme-mort/',
#  'https://www.mybeautifuljob.com/le-salaire-moyen-en-france-en-2021/',
#  'https://www.mybeautifuljob.com/les-disparites-du-salaire-des-agreges-selon-les-academies/',
#  'https://www.mybeautifuljob.com/evolution-de-la-paye-des-aed-quelles-nouvelles-en-2024/',
#  'https://www.mybeautifuljob.com/acceder-a-lent-rhone-alpes-astuces-pour-les-eleves/',
#  'https://www.mybeautifuljob.com/comparatif-2023-quel-est-le-meilleur-casque-antibruit-pour-le-travail-en-open-space/',
#  'https://www.mybeautifuljob.com/se-preparer-efficacement-pour-reussir-le-toeic-a-lyon/',
#  'https://www.mybeautifuljob.com/metier-en-k-explorons-les-opportunites-et-defis/',
#  'https://www.mybeautifuljob.com/cap-tournage-en-ceramique-formation-debouches-et-conseils/',
#  'https://www.mybeautifuljob.com/comprendre-le-syllogisme-juridique-definition-et-application-en-droit/',
#  'https://www.mybeautifuljob.com/delai-de-prevenance-comment-le-calculer/',
#  'https://www.mybeautifuljob.com/le-salaire-moyen-en-france-en-2021/',
#  'https://www.mybeautifuljob.com/cours-de-maths-a-domicile-pourquoi-passer-par-aladom/',
#  'https://www.mybeautifuljob.com/bts-commerce-international-explication-salaires-et-debouchees/',
#  'https://www.mybeautifuljob.com/comment-se-mettre-a-son-compte-sans-diplome/',
#  'https://www.mybeautifuljob.com/developper-ses-competences-pour-acceder-a-de-nouvelles-opportunites-sur-le-marche-du-travail-a-strasbourg/',
#  'https://www.mybeautifuljob.com/lms-unice-astuces-pour-une-utilisation-optimale/',
#  'https://www.mybeautifuljob.com/ages-bts-quels-sont-les-membres-les-plus-jeunes/',
#  'https://www.mybeautifuljob.com/limportance-cruciale-dun-tableau-des-metres-cubes-pour-evaluer-vos-volumes/',
#  'https://www.mybeautifuljob.com/comprendre-le-prix-de-lessec-frais-de-scolarite-et-investissements/',
#  'https://www.mybeautifuljob.com/relations-internationales-explorez-les-debouches-et-opportunites-de-carriere/',
#  'https://www.mybeautifuljob.com/la-woach-lapplication-de-kwark-education-pour-revolutionner-lapprentissage-des-etudiants/',
#  'https://www.mybeautifuljob.com/aide-financiere-de-la-caf-pour-le-permis-de-conduire-tout-ce-quil-faut-savoir/',
#  'https://www.mybeautifuljob.com/les-nombreux-benefices-de-la-formation-en-ligne-pour-se-former-efficacement/',
#  'https://www.mybeautifuljob.com/le-bts-commerce-international-un-tremplin-vers-une-carriere-internationale-reussie/',
#  'https://www.mybeautifuljob.com/vie-de-nomade-quel-metier-pour-voyager/',
#  'https://www.mybeautifuljob.com/mon-avis-sur-genius-cv-pour-la-creation-dun-cv-en-ligne/',
#  'https://www.mybeautifuljob.com/quel-livre-pour-preparer-le-crpe-2021/',
#  'https://www.mybeautifuljob.com/les-meilleurs-logiciels-pour-ecrire-son-cv/',
#  'https://www.mybeautifuljob.com/quelle-sont-les-demarches-pour-creer-son-entreprise/',
#  'https://www.mybeautifuljob.com/comprendre-levolution-de-la-remuneration-des-infirmiers-facteurs-et-perspectives-daugmentation/',
#  'https://www.mybeautifuljob.com/zoom-sur-le-salaire-moyen-dun-infirmier-liberal-realites-et-perspectives/',
#  'https://www.mybeautifuljob.com/cartes-vierges-de-la-france-decouvrir-des-astuces-pour-affiner-vos-connaissances-geographiques/',
#  'https://www.mybeautifuljob.com/les-metiers-commencant-par-c-un-tour-dhorizon/',
#  'https://www.mybeautifuljob.com/quel-est-le-role-dun-directeur-artistique-de-mode/',
#  'https://www.mybeautifuljob.com/bts-sam-gestion-de-projet-methodes-et-conseils-pratiques/',
#  'https://www.mybeautifuljob.com/exploration-du-salaire-moyen-dun-avocat-realites-et-perspectives/',
#  'https://www.mybeautifuljob.com/tarif-coaching-mental-combien-coute-un-accompagnement-professionnel/',
#  'https://www.mybeautifuljob.com/rediger-un-cv-daide-soignante-percutant-astuces-et-conseils/',
#  'https://www.mybeautifuljob.com/les-competences-essentielles-a-acquerir-pour-reussir-sa-reconversion-professionnelle/',
#  'https://www.mybeautifuljob.com/quest-ce-quun-technicien-irve/',
#  'https://www.mybeautifuljob.com/les-formations-express-pour-une-reconversion-eclair/',
#  'https://www.mybeautifuljob.com/pourquoi-le-stage-est-important/',
#  'https://www.mybeautifuljob.com/blended-learning-quest-ce-que-ca-signifie/',
#  'https://www.mybeautifuljob.com/quel-metier-faire-avec-un-bts-nrc/',
#  'https://www.mybeautifuljob.com/bts-commerce-international-explication-salaires-et-debouchees/',
#  'https://www.mybeautifuljob.com/one-to-one-en-marketing-quest-ce-que-cest/',
#  'https://www.mybeautifuljob.com/trouvez-un-emploi-chez-tellis-un-centre-dappels-en-correze/',
#  'https://www.mybeautifuljob.com/pourquoi-creer-une-auto-entreprise/',
#  'https://www.mybeautifuljob.com/exploration-des-opportunites-demplois-dans-le-secteur-du-tourisme-perspectives-et-defis/',
#  'https://www.mybeautifuljob.com/bts-comptabilite-et-gestion-explication-salaires-et-debouches/',
#  'https://www.mybeautifuljob.com/emprunter-le-chemin-de-lecriture-professionnelle-transformer-sa-passion-en-carriere-decrivain-public/',
#  'https://www.mybeautifuljob.com/maitriser-lart-des-mots-de-liaison-en-espagnol-pour-une-communication-fluide/',
#  'https://www.mybeautifuljob.com/comment-deposer-un-dossier-de-candidature-avec-ecandidat-avignon/',
#  'https://www.mybeautifuljob.com/verbe-faire-signification-et-conjugaison/',
#  'https://www.mybeautifuljob.com/quels-sont-les-metiers-les-mieux-payes/',
#  'https://www.mybeautifuljob.com/melanie2web-se-connecter-a-son-compte/',
#  'https://www.mybeautifuljob.com/plongee-au-coeur-de-pole-emploi-une-experience-immersive-inedite/',
#  'https://www.mybeautifuljob.com/les-debouches-professionnels-apres-une-formation-de-secretaire-medicale-en-alternance/',
#  'https://www.mybeautifuljob.com/comment-apprendre-larabe-en-samusant-les-jeux-et-applications-indispensables/',
#  'https://www.mybeautifuljob.com/comprendre-le-bts-salaire-en-alternance-une-equation-gagnante-pour-les-jeunes-talents/',
#  'https://www.mybeautifuljob.com/comment-decrocher-un-job-dete-pour-mineur-astuces-et-conseils/',
#  'https://www.mybeautifuljob.com/les-defis-et-les-opportunites-de-la-formation-dauxiliaire-de-puericulture-en-alternance/',
#  'https://www.mybeautifuljob.com/comment-une-formation-intensive-peut-booster-votre-carriere-en-gestion-de-produit/',
#  'https://www.mybeautifuljob.com/opticien-et-si-vous-deveniez-itinerant/',
#  'https://www.mybeautifuljob.com/5-idees-de-reconversion-pour-un-metier-plus-epanouissant/',
#  'https://www.mybeautifuljob.com/optimiser-sa-strategie-de-recrutement-grace-a-pole-emploi-conseils-et-astuces/',
#  'https://www.mybeautifuljob.com/pourquoi-la-reconversion-professionnelle-est-plus-accessible-que-vous-ne-le-pensez/',
#  'https://www.mybeautifuljob.com/normes-hse-en-entreprise-comprendre-et-appliquer-les-regulations-de-sante-securite-et-environnement/',
#  'https://www.mybeautifuljob.com/que-faut-il-savoir-concretement-par-rapport-a-lassistante-dentaire/',
#  'https://www.mybeautifuljob.com/delai-de-prevenance-comment-le-calculer/',
#  'https://www.mybeautifuljob.com/le-salaire-moyen-en-france-en-2021/',
#  'https://www.mybeautifuljob.com/cours-de-maths-a-domicile-pourquoi-passer-par-aladom/',
#  'https://www.mybeautifuljob.com/bts-commerce-international-explication-salaires-et-debouchees/',
#  'https://www.mybeautifuljob.com/comment-se-mettre-a-son-compte-sans-diplome/',
#  'https://www.mybeautifuljob.com/developper-ses-competences-pour-acceder-a-de-nouvelles-opportunites-sur-le-marche-du-travail-a-strasbourg/',
#  'https://www.mybeautifuljob.com/lms-unice-astuces-pour-une-utilisation-optimale/',
#  'https://www.mybeautifuljob.com/ages-bts-quels-sont-les-membres-les-plus-jeunes/',
#  'https://www.mybeautifuljob.com/limportance-cruciale-dun-tableau-des-metres-cubes-pour-evaluer-vos-volumes/',
#  'https://www.mybeautifuljob.com/comprendre-le-prix-de-lessec-frais-de-scolarite-et-investissements/',
#  'https://www.mybeautifuljob.com/cours-de-maths-a-domicile-pourquoi-passer-par-aladom/',
#  'https://www.mybeautifuljob.com/quel-interet-de-travailler-dans-plusieurs-entreprises/',
#  'https://www.mybeautifuljob.com/les-perspectives-devolution-apres-un-bts-ndrc/',
#  'https://www.mybeautifuljob.com/scrumban-explique-methodologie-avantages-et-exemples-pratiques/',
#  'https://www.mybeautifuljob.com/evenement-dentreprise-se-servir-dobjets-publicitaires/',
#  'https://www.mybeautifuljob.com/une-gestion-financiere-efficace-pour-securiser-lavenir-de-votre-entreprise/',
#  'https://www.mybeautifuljob.com/apprendre-une-nouvelle-langue-a-montpellier-les-meilleures-options/',
#  'https://www.mybeautifuljob.com/les-secrets-de-mon-college-val-doise-reinventer-leducation/',
#  'https://www.mybeautifuljob.com/percez-dans-lindustrie-de-la-beaute-les-meilleures-offres-demploi-en-coiffure-du-moment/',
#  'https://www.mybeautifuljob.com/decouvrez-les-fonctionnalites-avancees-de-mycampus-eduservices-org/',
#  'https://www.mybeautifuljob.com/formuler-une-candidature-eloquente-pour-une-admission-en-classe-de-seconde/',
#  'https://www.mybeautifuljob.com/pourquoi-choisir-des-lunettes-de-soleil-personnalisees-pour-vos-evenements-dentreprise/',
#  'https://www.mybeautifuljob.com/les-opportunites-de-carriere-dans-le-secteur-non-lucratif-a-lyon/',
#  'https://www.mybeautifuljob.com/eclairer-lessence-dun-ouvrage-les-secrets-des-resumes-de-livres/',
#  'https://www.mybeautifuljob.com/les-etudes-en-comptabilite-un-tremplin-vers-des-opportunites-strategiques/',
#  'https://www.mybeautifuljob.com/comprendre-le-systeme-du-pai-un-outil-cle-de-leducation-nationale/',
#  'https://www.mybeautifuljob.com/suivre-une-formation-en-cybersecurite-quels-benefices/',
#  'https://www.mybeautifuljob.com/coaching-intuitif-pour-qui-est-il-destine-et-ses-bienfaits-essentiels/',
#  'https://www.mybeautifuljob.com/comment-choisir-le-meilleur-cahier-seyes-pour-votre-enfant/',
#  'https://www.mybeautifuljob.com/levolution-du-marche-de-la-formation-professionnelle-une-analyse-approfondie-des-tendances-actuelles-et-des-perspectives-a-lechelle-nationale-et-internationale/',
#  'https://www.mybeautifuljob.com/optimiser-ses-revisions-en-droit-grace-a-un-soutien-personnalise/',
#  'https://www.mybeautifuljob.com/cours-darabe-en-ligne-comparatif-des-plateformes-les-plus-efficaces/',
#  'https://www.mybeautifuljob.com/ameliorer-vos-competences-artistiques-pourquoi-opter-pour-une-formation-en-graphisme-a-angers/',
#  'https://www.mybeautifuljob.com/entreprise-pourquoi-organiser-un-seminaire-annuel/',
#  'https://www.mybeautifuljob.com/decrocher-une-offre-demploi-pour-enseignant-contractuel-strategies-et-conseils-pratiques/',
#  'https://www.mybeautifuljob.com/les-competences-essentielles-a-cultiver-pour-exceller-professionnellement/',
#  'https://www.mybeautifuljob.com/trouver-le-metier-qui-vous-correspond/',
#  'https://www.mybeautifuljob.com/comment-decrocher-le-job-de-vos-reves-dans-une-grande-ville-francaise/',
#  'https://www.mybeautifuljob.com/comment-concilier-etudes-et-travail-a-temps-partiel-focus-sur-les-opportunites-en-region-rhone-alpes/',
#  'https://www.mybeautifuljob.com/la-bonne-gestion-des-ressources-humaines-pour-les-tpe-pme-un-levier-de-competitivite-incontournable/',
#  'https://www.mybeautifuljob.com/les-avantages-dutiliser-un-logiciel-de-gestion-de-projet-dans-votre-equipe/',
#  'https://www.mybeautifuljob.com/lart-de-la-presentation-visuelle-tableau-a-craie-esco-et-techniques-infaillibles/',
#  'https://www.mybeautifuljob.com/comment-utiliser-7-x-8-pour-maximiser-lefficacite-pedagogique/',
#  'https://www.mybeautifuljob.com/limportance-de-la-micronutrition-dans-le-domaine-de-la-sante/',
#  'https://www.mybeautifuljob.com/chef-de-produit-comment-le-devenir/',
#  'https://www.mybeautifuljob.com/la-reconversion-professionnelle-un-tremplin-vers-de-nouvelles-opportunites/',
#  'https://www.mybeautifuljob.com/les-avantages-de-faire-une-formation-logistique-en-alternance/',
#  'https://www.mybeautifuljob.com/decouvrez-les-differentes-options-de-formation-professionnelle-disponibles/',
#  'https://www.mybeautifuljob.com/comment-choisir-la-meilleure-specialisation-en-informatique-pour-des-etudes-superieures/',
#  'https://www.mybeautifuljob.com/formation-de-conducteur-gerbeur-comment-la-faire/',
#  'https://www.mybeautifuljob.com/comment-choisir-le-meilleur-organisme-de-formation/',
#  'https://www.mybeautifuljob.com/imprimeur-a-paris-trouver-le-meilleur-imprimeur/',
#  'https://www.mybeautifuljob.com/combien-coutent-les-services-dun-avocat/',
#  'https://www.mybeautifuljob.com/equilibre-vie-professionnelle-vie-personnelle-un-defi-dans-les-metiers-medicaux/',
#  'https://www.mybeautifuljob.com/se-former-pour-lavenir-les-meilleures-formations-pour-une-carriere-dans-la-transition-ecologique/',
#  'https://www.mybeautifuljob.com/comprendre-le-design-thinking-methodes-et-avantages-pour-linnovation/',
#  'https://www.mybeautifuljob.com/innovation-et-soins-evoluez-dans-un-secteur-en-constante-mutation/',
#  'https://www.mybeautifuljob.com/pedagogie-reggio-expliquee-principes-et-mise-en-oeuvre-efficace/',
#  'https://www.mybeautifuljob.com/top-applications-pour-apprentissage-linguistique-choisissez-efficacement/',
#  'https://www.mybeautifuljob.com/reussir-un-cas-pratique-en-droit-astuces-et-methodologie-efficace/',
#  'https://www.mybeautifuljob.com/delai-de-prevenance-comment-le-calculer/',
#  'https://www.mybeautifuljob.com/le-salaire-moyen-en-france-en-2021/',
#  'https://www.mybeautifuljob.com/cours-de-maths-a-domicile-pourquoi-passer-par-aladom/',
#  'https://www.mybeautifuljob.com/bts-commerce-international-explication-salaires-et-debouchees/',
#  'https://www.mybeautifuljob.com/comment-se-mettre-a-son-compte-sans-diplome/',
#  'https://www.mybeautifuljob.com/developper-ses-competences-pour-acceder-a-de-nouvelles-opportunites-sur-le-marche-du-travail-a-strasbourg/',
#  'https://www.mybeautifuljob.com/lms-unice-astuces-pour-une-utilisation-optimale/',
#  'https://www.mybeautifuljob.com/ages-bts-quels-sont-les-membres-les-plus-jeunes/',
#  'https://www.mybeautifuljob.com/limportance-cruciale-dun-tableau-des-metres-cubes-pour-evaluer-vos-volumes/',
#  'https://www.mybeautifuljob.com/comprendre-le-prix-de-lessec-frais-de-scolarite-et-investissements/',
#  'https://www.mybeautifuljob.com/methode-montessori-principes-et-mise-en-oeuvre-efficace-en-education/',
#  'https://www.mybeautifuljob.com/reussir-loral-danglais-5-strategies-cles-pour-exceller/',
#  'https://www.mybeautifuljob.com/comment-valoriser-votre-experience-pour-devenir-auditeur/',
#  'https://www.mybeautifuljob.com/quel-est-le-meilleur-centre-de-formation-a-strasbourg-specialise-dans-les-formations-learner-centric/',
#  'https://www.mybeautifuljob.com/les-programmes-specialises-des-ecoles-de-commerce-quel-parcours-pour-quel-metier/',
#  'https://www.mybeautifuljob.com/les-debouches-professionnels-apres-des-etudes-en-ecole-de-commerce-et-de-management/',
#  'https://www.mybeautifuljob.com/reussir-le-crfpa-strategies-et-conseils-pour-le-concours-davocat/',
#  'https://www.mybeautifuljob.com/formation-hotesse-de-lair-steward-parcours-et-astuces-pour-reussir/',
#  'https://www.mybeautifuljob.com/prix-formation-125cc-cout-et-details-pour-conduire-un-scooter-ou-moto-legere/',
#  'https://www.mybeautifuljob.com/que-fait-une-secretaire-medicale-au-quotidien/',
#  'https://www.mybeautifuljob.com/top-applications-pour-apprentissage-linguistique-choisissez-la-meilleure/',
#  'https://www.mybeautifuljob.com/comment-amenager-un-accueil-dentreprise-qui-seduit-les-clients/',
#  'https://www.mybeautifuljob.com/coach-professionnel-missions-techniques-et-impact-du-coaching-efficace/',
#  'https://www.mybeautifuljob.com/apprendre-le-piano-5-bienfaits-pour-le-cerveau/',
#  'https://www.mybeautifuljob.com/comment-faire-pour-creer-son-cv-en-ligne/',
#  'https://www.mybeautifuljob.com/les-meilleures-formations-devops-en-2024-le-top-3-pour-booster-votre-carriere-dans-la-tech/',
#  'https://www.mybeautifuljob.com/pourquoi-et-comment-realiser-un-test-damiante-a-montreal/',
#  'https://www.mybeautifuljob.com/apprendre-le-piano-seul-ou-avec-une-ecole-specialisee/',
#  'https://www.mybeautifuljob.com/la-formation-a-linnovation-pour-les-entreprises-tout-ce-que-vous-devez-savoir/',
#  'https://www.mybeautifuljob.com/entreprenariat-responsable-que-dit-la-loi-sur-la-vaisselle-jetable-pour-les-repas-servis-sur-place/',
#  'https://www.mybeautifuljob.com/economie-energetique-comment-leffacement-electrique-transforme-les-entreprises/',
#  'https://www.mybeautifuljob.com/ameliorer-son-developpement-personnel-grace-a-la-formation-lessentiel-a-savoir/',
#  'https://www.mybeautifuljob.com/les-differentes-options-de-financement-pour-la-formation-professionnelle/',
#  'https://www.mybeautifuljob.com/les-methodes-dapprentissage-et-leurs-impacts-sur-la-memorisation/',
#  'https://www.mybeautifuljob.com/les-avantages-cles-de-linvestissement-dans-la-formation-continue-pour-les-entreprises/',
#  'https://www.mybeautifuljob.com/les-meilleures-formations-pour-une-reconversion-reussie-dans-des-secteurs-davenir/',
#  'https://www.mybeautifuljob.com/quels-sont-les-metiers-les-plus-demandes-en-interim/',
#  'https://www.mybeautifuljob.com/trouver-un-emploi-a-ploermel-conseils-offres-et-opportunites-professionnelles/',
#  'https://www.mybeautifuljob.com/5-raisons-de-choisir-une-carriere-dinfirmiere/',
#  'https://www.mybeautifuljob.com/quest-ce-quun-officier-en-chef-du-bonheur/',
#  'https://www.mybeautifuljob.com/trouver-un-emploi-a-belleville-en-beaujolais-conseils-et-opportunites/',
#  'https://www.mybeautifuljob.com/toefl-quatre-raisons-de-passer-ce-test/',
#  'https://www.mybeautifuljob.com/les-competences-incontournables-pour-reussir-sur-le-marche-du-travail/',
#  'https://www.mybeautifuljob.com/les-meilleures-facons-de-financer-sa-formation-professionnelle/',
#  'https://www.mybeautifuljob.com/les-metiers-du-futur-et-les-formations-pour-sy-preparer/',
#  'https://www.mybeautifuljob.com/guide-ultime-pour-choisir-la-meilleure-formation-professionnelle/',
#  'https://www.mybeautifuljob.com/passionne-de-bien-etre-et-si-vous-deveniez-naturopathe/',
#  'https://www.mybeautifuljob.com/trouver-la-formation-ideale-pour-atteindre-vos-objectifs/',
#  'https://www.mybeautifuljob.com/les-dernieres-avancees-technologiques-au-service-de-la-formation/',
#  'https://www.mybeautifuljob.com/les-formations-incontournables-pour-booster-votre-carriere-professionnelle/',
#  'https://www.mybeautifuljob.com/trouver-la-formation-ideale-pour-propulser-votre-carriere/',
#  'https://www.mybeautifuljob.com/les-multiples-atouts-de-la-formation-en-ligne-pour-booster-votre-activite-entrepreneuriale/',
#  'https://www.mybeautifuljob.com/trouver-la-formation-ideale-pour-atteindre-ses-objectifs-professionnels/',
#  'https://www.mybeautifuljob.com/les-meilleures-strategies-pour-maximiser-son-apprentissage-en-formation/',
#  'https://www.mybeautifuljob.com/les-benefices-de-la-formation-en-interne-pour-les-entreprises/',
#  'https://www.mybeautifuljob.com/les-methodes-daccompagnement-pour-reussir-sa-reconversion-professionnelle/',
#  'https://www.mybeautifuljob.com/comment-rediger-un-cv-sans-experience/',
#  'https://www.mybeautifuljob.com/obtenir-son-acte-de-naissance-quand-on-est-ne-a-letranger/',
#  'https://www.mybeautifuljob.com/les-meilleurs-outils-pour-apprendre-a-se-connaitre-soi-meme/',
#  'https://www.mybeautifuljob.com/les-meilleures-astuces-pour-optimiser-le-roi-dune-formation-en-entreprise/',
#  'https://www.mybeautifuljob.com/delai-de-prevenance-comment-le-calculer/',
#  'https://www.mybeautifuljob.com/le-salaire-moyen-en-france-en-2021/',
#  'https://www.mybeautifuljob.com/cours-de-maths-a-domicile-pourquoi-passer-par-aladom/',
#  'https://www.mybeautifuljob.com/bts-commerce-international-explication-salaires-et-debouchees/',
#  'https://www.mybeautifuljob.com/comment-se-mettre-a-son-compte-sans-diplome/',
#  'https://www.mybeautifuljob.com/developper-ses-competences-pour-acceder-a-de-nouvelles-opportunites-sur-le-marche-du-travail-a-strasbourg/',
#  'https://www.mybeautifuljob.com/lms-unice-astuces-pour-une-utilisation-optimale/',
#  'https://www.mybeautifuljob.com/ages-bts-quels-sont-les-membres-les-plus-jeunes/',
#  'https://www.mybeautifuljob.com/limportance-cruciale-dun-tableau-des-metres-cubes-pour-evaluer-vos-volumes/',
#  'https://www.mybeautifuljob.com/comprendre-le-prix-de-lessec-frais-de-scolarite-et-investissements/',
#  'https://www.mybeautifuljob.com/les-aides-et-dispositifs-pour-financer-sa-formation-guide-complet/',
#  'https://www.mybeautifuljob.com/les-meilleures-formations-pour-decrocher-rapidement-un-emploi/',
#  'https://www.mybeautifuljob.com/les-avantages-dune-formation-continue-pour-booster-sa-carriere/',
#  'https://www.mybeautifuljob.com/choisissez-la-formation-professionnelle-qui-vous-convient-le-mieux-avec-ces-conseils-adaptes/',
#  'https://www.mybeautifuljob.com/les-certifications-incontournables-pour-dynamiser-votre-cv-et-vos-opportunites-professionnelles/',
#  'https://www.mybeautifuljob.com/quels-metiers-peut-on-faire-apres-un-bts-en-commerce-international/',
#  'https://www.mybeautifuljob.com/integration-des-medias-sociaux-dans-les-lms/',
#  'https://www.mybeautifuljob.com/comment-trouver-du-travail-en-tant-que-francais-a-montreal/',
#  'https://www.mybeautifuljob.com/pourquoi-faire-appel-a-un-cabinet-daudit/',
#  'https://www.mybeautifuljob.com/les-metiers-les-plus-recherches-du-moment-et-les-formations-correspondantes/',
#  'https://www.mybeautifuljob.com/quelle-est-la-particularite-dun-site-doffres-demploi/',
#  'https://www.mybeautifuljob.com/trouver-un-emploi-a-ploermel-offres-conseils-et-opportunites-professionnelles/',
#  'https://www.mybeautifuljob.com/les-formations-les-plus-prisees-sur-le-marche-de-lemploi/',
#  'https://www.mybeautifuljob.com/les-pieges-a-eviter-lors-dune-formation-professionnelle/',
#  'https://www.mybeautifuljob.com/formation-en-presentiel-vs-formation-en-ligne-les-benefices-et-limites-a-considerer/',
#  'https://www.mybeautifuljob.com/optimisez-votre-apprentissage-les-cles-dune-formation-reussie/',
#  'https://www.mybeautifuljob.com/utilisation-dexcel-dans-une-pme/',
#  'https://www.mybeautifuljob.com/limportance-de-la-formation-continue-pour-une-carriere-epanouie/',
#  'https://www.mybeautifuljob.com/limportance-cruciale-de-la-formation-continue-pour-sadapter-a-un-monde-en-constante-mutation/',
#  'https://www.mybeautifuljob.com/evaluation-de-la-qualite-dune-formation-criteres-essentiels-a-prendre-en-compte/',
#  'https://www.mybeautifuljob.com/quelle-formation-pour-devenir-un-juriste-specialise/',
#  'https://www.mybeautifuljob.com/comment-apprendre-rapidement-langlais/',
#  'https://www.mybeautifuljob.com/les-competences-essentielles-a-connaitre-et-a-developper-pour-reussir-sur-le-marche-du-travail/',
#  'https://www.mybeautifuljob.com/comment-denicher-une-bonne-offre-demploi/',
#  'https://www.mybeautifuljob.com/les-cles-essentielles-de-la-formation-en-leadership-pour-les-entrepreneurs-en-plein-essor/',
#  'https://www.mybeautifuljob.com/valoriser-une-formation-les-cles-pour-briller-sur-votre-cv-et-lors-dun-entretien-dembauche/',
#  'https://www.mybeautifuljob.com/les-nombreux-benefices-de-la-formation-continue-pour-le-developpement-de-sa-carriere-professionnelle/',
#  'https://www.mybeautifuljob.com/pourquoi-passer-par-une-agence-dinterim/',
#  'https://www.mybeautifuljob.com/comment-se-former-a-la-medecine-chinoise/',
#  'https://www.mybeautifuljob.com/integrer-la-formation-dans-la-strategie-globale-de-lentreprise-les-cles-de-la-reussite/',
#  'https://www.mybeautifuljob.com/faut-il-entreprendre-seul-ou-avec-un-associe/',
#  'https://www.mybeautifuljob.com/les-competences-transversales-un-atout-indispensable-pour-votre-developpement-professionnel/',
#  'https://www.mybeautifuljob.com/les-formations-en-alternance-une-opportunite-unique-pour-concilier-etudes-et-emploi/',
#  'https://www.mybeautifuljob.com/trouver-la-formation-ideale-pour-repondre-a-vos-besoins-nos-conseils-essentiels/',
#  'https://www.mybeautifuljob.com/les-cles-pour-maximiser-votre-retour-sur-investissement-en-formation/',
#  'https://www.mybeautifuljob.com/les-dernieres-tendances-en-matiere-de-formation-professionnelle-qui-revolutionnent-le-marche/',
#  'https://www.mybeautifuljob.com/comment-savoir-si-vous-etes-fait-pour-le-metier-de-naturopathe/',
#  'https://www.mybeautifuljob.com/developper-ses-competences-relationnelles-grace-aux-formations-en-soft-skills/',
#  'https://www.mybeautifuljob.com/pourquoi-appartenir-a-une-association-de-management/',
#  'https://www.mybeautifuljob.com/le-management-sans-hierarchie-est-il-possible/',
#  'https://www.mybeautifuljob.com/5-astuces-pour-une-lettre-de-motivation-bien-redigee/',
#  'https://www.mybeautifuljob.com/les-cles-dun-programme-de-formation-performant-en-entreprise/',
#  'https://www.mybeautifuljob.com/les-dernieres-tendances-en-matiere-de-formation-professionnelle-a-connaitre/',
#  'https://www.mybeautifuljob.com/developper-ses-soft-skills-et-son-intelligence-emotionnelle-limportance-des-formations-specialisees/',
#  'https://www.mybeautifuljob.com/les-bienfaits-de-la-formation-continue-pour-dynamiser-sa-carriere/',
#  'https://www.mybeautifuljob.com/accedez-au-crpe-et-devenez-professeur-des-ecoles-primaires/',
#  'https://www.mybeautifuljob.com/limportance-cruciale-de-la-formation-en-entreprise-pour-la-fidelisation-des-employes/',
#  'https://www.mybeautifuljob.com/ameliorez-lefficacite-de-votre-entreprise-grace-a-des-formations-en-gestion-de-projet/',
#  'https://www.mybeautifuljob.com/trouver-un-emploi-a-chartres-conseils-offres-et-recrutement/',
#  'https://www.mybeautifuljob.com/conseils-pour-une-recherche-de-formation-professionnelle-reussie-et-sans-faute/',
#  'https://www.mybeautifuljob.com/delai-de-prevenance-comment-le-calculer/',
#  'https://www.mybeautifuljob.com/le-salaire-moyen-en-france-en-2021/',
#  'https://www.mybeautifuljob.com/cours-de-maths-a-domicile-pourquoi-passer-par-aladom/',
#  'https://www.mybeautifuljob.com/bts-commerce-international-explication-salaires-et-debouchees/',
#  'https://www.mybeautifuljob.com/comment-se-mettre-a-son-compte-sans-diplome/',
#  'https://www.mybeautifuljob.com/developper-ses-competences-pour-acceder-a-de-nouvelles-opportunites-sur-le-marche-du-travail-a-strasbourg/',
#  'https://www.mybeautifuljob.com/lms-unice-astuces-pour-une-utilisation-optimale/',
#  'https://www.mybeautifuljob.com/ages-bts-quels-sont-les-membres-les-plus-jeunes/',
#  'https://www.mybeautifuljob.com/limportance-cruciale-dun-tableau-des-metres-cubes-pour-evaluer-vos-volumes/',
#  'https://www.mybeautifuljob.com/comprendre-le-prix-de-lessec-frais-de-scolarite-et-investissements/',
#  'https://www.mybeautifuljob.com/comment-la-prolongation-de-la-validite-de-lexamen-de-code-de-la-route-facilite-lapprentissage-des-conducteurs/',
#  'https://www.mybeautifuljob.com/quels-sont-les-principaux-avantages-de-laide-aux-devoirs/',
#  'https://www.mybeautifuljob.com/decouvrez-les-dernieres-tendances-des-formations-professionnelles-pour-booster-votre-carriere/',
#  'https://www.mybeautifuljob.com/les-formations-en-management-pour-augmenter-son-potentiel-professionnel/',
#  'https://www.mybeautifuljob.com/comment-se-former-efficacement-pour-travailler-dans-le-tourisme-a-letranger/',
#  'https://www.mybeautifuljob.com/decouvrez-les-dispositifs-de-financement-pour-faciliter-lacces-a-la-formation-professionnelle/',
#  'https://www.mybeautifuljob.com/les-pieges-a-eviter-lors-de-votre-choix-de-formation/',
#  'https://www.mybeautifuljob.com/les-competences-indispensables-pour-exceller-en-tant-que-chef-dentreprise/',
#  'https://www.mybeautifuljob.com/comment-devenir-un-meilleur-vendeur/',
#  'https://www.mybeautifuljob.com/6-conseils-pour-reussir-votre-lettre-de-motivation/',
#  'https://www.mybeautifuljob.com/formation-professionnelle-en-entreprise-avantages-et-limites-a-connaitre/',
#  'https://www.mybeautifuljob.com/les-meilleures-formations-pour-entreprendre-et-creer-son-entreprise/',
#  'https://www.mybeautifuljob.com/formations-pour-exceller-dans-son-domaine-les-cles-pour-surpasser-la-concurrence/',
#  'https://www.mybeautifuljob.com/valoriser-efficacement-sa-formation-conseils-pour-un-cv-et-un-entretien-reussis/',
#  'https://www.mybeautifuljob.com/limportance-de-la-formation-continue-pour-maintenir-sa-competitivite-sur-le-marche-du-travail/',
#  'https://www.mybeautifuljob.com/valorisez-vos-competences-acquises-en-formation-pour-optimiser-votre-cv-et-reussir-vos-entretiens-dembauche/',
#  'https://www.mybeautifuljob.com/les-avantages-detudier-le-maquillage-dans-une-ecole-specialisee/',
#  'https://www.mybeautifuljob.com/les-dernieres-evolutions-dans-le-domaine-de-la-formation-professionnelle/',
#  'https://www.mybeautifuljob.com/comment-bien-choisir-sa-formation-en-alternance-en-banque-et-commerce/',
#  'https://www.mybeautifuljob.com/les-astuces-pour-apprendre-efficacement-via-les-nouveaux-outils-numeriques/',
#  'https://www.mybeautifuljob.com/les-competences-indispensables-pour-prosperer-dans-lunivers-des-affaires/',
#  'https://www.mybeautifuljob.com/developpez-vos-competences-digitales-grace-aux-formations-adaptees/',
#  'https://www.mybeautifuljob.com/conseils-pour-trouver-un-emploi-dans-la-region-de-dole/',
#  'https://www.mybeautifuljob.com/optimisation-de-la-productivite-des-employes-decouvrez-les-methodes-de-formation-les-plus-efficaces/',
#  'https://www.mybeautifuljob.com/les-competences-essentielles-recherchees-par-les-employeurs-sur-le-marche-du-travail/',
#  'https://www.mybeautifuljob.com/formation-en-ligne-vs-formation-en-presentiel-decryptage-des-atouts-et-des-limites/',
#  'https://www.mybeautifuljob.com/les-tendances-emergentes-en-formation-continue-qui-vous-garantiront-un-avantage-concurrentiel/',
#  'https://www.mybeautifuljob.com/lindispensable-formation-continue-pour-maintenir-son-expertise-a-jour/',
#  'https://www.mybeautifuljob.com/developper-ses-soft-skills-pour-une-meilleure-performance-professionnelle-grace-a-la-formation-continue/',
#  'https://www.mybeautifuljob.com/optimiser-son-budget-formation-les-cles-pour-evaluer-son-retour-sur-investissement/',
#  'https://www.mybeautifuljob.com/les-principales-tendances-de-la-formation-professionnelle-continue-en-entreprise/',
#  'https://www.mybeautifuljob.com/5-conseils-pour-devenir-coach-sportif/',
#  'https://www.mybeautifuljob.com/les-tendances-actuelles-du-marche-du-travail-en-france/',
#  'https://www.mybeautifuljob.com/les-avantages-des-formations-en-ligne-pour-se-former-efficacement-a-distance/',
#  'https://www.mybeautifuljob.com/les-cles-pour-trouver-la-formation-ideale-et-booster-votre-entreprise/',
#  'https://www.mybeautifuljob.com/valoriser-ses-competences-acquises-en-formation-pour-booster-sa-carriere-professionnelle/',
#  'https://www.mybeautifuljob.com/acquerir-les-competences-cles-en-formation-professionnelle-ce-que-vous-devez-savoir/',
#  'https://www.mybeautifuljob.com/selectionner-la-meilleure-formation-pour-son-entreprise-guide-et-conseils/',
#  'https://www.mybeautifuljob.com/decouvrez-les-metiers-accessibles-apres-un-bts-en-gestion-et-protection-de-la-nature/',
#  'https://www.mybeautifuljob.com/les-competences-cles-a-acquerir-pour-se-former-aux-metiers-du-graphisme/',
#  'https://www.mybeautifuljob.com/des-conseils-pour-rediger-un-cv-percutant/',
#  'https://www.mybeautifuljob.com/pourquoi-opter-pour-une-formation-en-microblading/',
#  'https://www.mybeautifuljob.com/les-nouvelles-pratiques-en-matiere-de-formation-professionnelle-ces-dernieres-annees/',
#  'https://www.mybeautifuljob.com/faut-il-un-diplome-pour-travailler-dans-lhotellerie/',
#  'https://www.mybeautifuljob.com/ameliorer-la-performance-et-la-productivite-de-votre-entreprise-grace-aux-formations/',
#  'https://www.mybeautifuljob.com/quelles-conditions-sont-requises-pour-obtenir-un-credit-a-la-consommation/',
#  'https://www.mybeautifuljob.com/lessor-de-la-formation-continue-un-atout-indispensable-pour-rester-competitif-dans-le-monde-des-affaires/',
#  'https://www.mybeautifuljob.com/un-cabinet-de-recrutement-pour-trouver-les-bons-talents-une-solution-rentable/',
#  'https://www.mybeautifuljob.com/reussir-le-tournant-vers-les-etudes-superieures/',
#  'https://www.mybeautifuljob.com/pourquoi-broder-vos-chemises-dentreprise/',
#  'https://www.mybeautifuljob.com/delai-de-prevenance-comment-le-calculer/',
#  'https://www.mybeautifuljob.com/le-salaire-moyen-en-france-en-2021/',
#  'https://www.mybeautifuljob.com/cours-de-maths-a-domicile-pourquoi-passer-par-aladom/',
#  'https://www.mybeautifuljob.com/bts-commerce-international-explication-salaires-et-debouchees/',
#  'https://www.mybeautifuljob.com/comment-se-mettre-a-son-compte-sans-diplome/',
#  'https://www.mybeautifuljob.com/developper-ses-competences-pour-acceder-a-de-nouvelles-opportunites-sur-le-marche-du-travail-a-strasbourg/',
#  'https://www.mybeautifuljob.com/lms-unice-astuces-pour-une-utilisation-optimale/',
#  'https://www.mybeautifuljob.com/ages-bts-quels-sont-les-membres-les-plus-jeunes/',
#  'https://www.mybeautifuljob.com/limportance-cruciale-dun-tableau-des-metres-cubes-pour-evaluer-vos-volumes/',
#  'https://www.mybeautifuljob.com/comprendre-le-prix-de-lessec-frais-de-scolarite-et-investissements/',
#  'https://www.mybeautifuljob.com/mesurer-les-retombees-dune-formation-sur-votre-vie-professionnelle-les-cles-pour-evaluer-votre-investissement/',
#  'https://www.mybeautifuljob.com/les-meilleures-options-pour-financer-votre-formation-professionnelle/',
#  'https://www.mybeautifuljob.com/les-avantages-du-sport-comme-activite-de-team-building-en-entreprise/',
#  'https://www.mybeautifuljob.com/les-atouts-de-la-formation-en-ligne-pour-apprendre-a-distance/',
#  'https://www.mybeautifuljob.com/pourquoi-passer-par-un-cabinet-dexpert-comptable-pour-sa-comptabilite/',
#  'https://www.mybeautifuljob.com/recrutement-digital-comment-selectionner-un-chef-de-projet-digital/',
#  'https://www.mybeautifuljob.com/les-cles-pour-reussir-dans-les-metiers-en-evolution-rapide-grace-a-la-formation-professionnelle/',
#  'https://www.mybeautifuljob.com/se-cultiver-pour-mieux-gerer-son-entreprise/',
#  'https://www.mybeautifuljob.com/impliquer-les-employes-dans-les-programmes-de-formation-strategies-efficaces-pour-un-engagement-optimal/',
#  'https://www.mybeautifuljob.com/comment-diriger-un-groupe-de-travail/',
#  'https://www.mybeautifuljob.com/formation-en-ligne-vs-formation-en-presentiel-avantages-et-inconvenients-compares/',
#  'https://www.mybeautifuljob.com/brightspace-systeme-lms-learning-management-system/',
#  'https://www.mybeautifuljob.com/lesthetique-en-belgique-comment-choisir-la-formation-qui-vous-convient-le-mieux/',
#  'https://www.mybeautifuljob.com/comment-se-former-rapidement-aux-nouveaux-metiers/',
#  'https://www.mybeautifuljob.com/aspirants-professionnels-de-lhotellerie-pourquoi-un-bachelor-est-il-lideal/',
#  'https://www.mybeautifuljob.com/trois-astuces-pour-ameliorer-les-performances-commerciales-dune-entreprise/',
#  'https://www.mybeautifuljob.com/comment-bien-gerer-son-commerce-en-ligne/',
#  'https://www.mybeautifuljob.com/formation-marketing-mobile/',
#  'https://www.mybeautifuljob.com/la-qvt-et-ses-bienfaits/',
#  'https://www.mybeautifuljob.com/conseils-faciles-pour-trouver-un-emploi-apres-la-pandemie/',
#  'https://www.mybeautifuljob.com/former-les-collaborateurs-en-entreprise-quels-sont-les-avantages-dune-plateforme/',
#  'https://www.mybeautifuljob.com/recrutement-de-personnel-pour-entreprises-trois-astuces-pour-reussir-cette-tache/',
#  'https://www.mybeautifuljob.com/apprendre-langlais-pour-se-professionnaliser/',
#  'https://www.mybeautifuljob.com/comment-alleger-ses-credits-grace-a-la-strategie-de-lassociation/',
#  'https://www.mybeautifuljob.com/recourir-a-un-notaire-3-raisons-de-contacter-ce-professionnel/',
#  'https://www.mybeautifuljob.com/financer-sa-formation-professionnelle-les-solutions-a-connaitre/',
#  'https://www.mybeautifuljob.com/ou-suivre-une-formation-en-gestes-et-postures/',
#  'https://www.mybeautifuljob.com/quels-sont-les-avantages-de-se-faire-former-dans-une-ecole-du-web/',
#  'https://www.mybeautifuljob.com/comment-bien-choisir-son-contrat-dassurance-vie/',
#  'https://www.mybeautifuljob.com/pourquoi-sinteresser-au-tic/',
#  'https://www.mybeautifuljob.com/demandeur-demploi-pourquoi-faire-une-formation/',
#  'https://www.mybeautifuljob.com/pourquoi-suivre-une-formation-pour-devenir-directeur-artistique-de-mode/',
#  'https://www.mybeautifuljob.com/pourquoi-suivre-une-formation-dans-une-ecole-de-cinema/',
#  'https://www.mybeautifuljob.com/quelles-sont-les-qualites-dun-courtier-en-tresorerie/',
#  'https://www.mybeautifuljob.com/les-programmes-de-formation-pour-faciliter-la-reconversion-professionnelle-des-travailleurs/',
#  'https://www.mybeautifuljob.com/les-tendances-de-la-formation-en-entreprise-comment-les-anticiper-et-les-integrer-dans-votre-strategie-de-developpement/',
#  'https://www.mybeautifuljob.com/naviguer-sur-le-marche-immobilier-francais-conseils-pour-les-acheteurs-etrangers/',
#  'https://www.mybeautifuljob.com/industrie-le-domaine-de-la-supply-chain-est-il-fait-pour-vous/',
#  'https://www.mybeautifuljob.com/comment-former-ses-collaborateurs/',
#  'https://www.mybeautifuljob.com/une-formation-a-la-transition-ecologique-des-debouches-a-remuneration-attrayants/',
#  'https://www.mybeautifuljob.com/les-logiciels-utilises-par-le-directeur-artistique-numerique/',
#  'https://www.mybeautifuljob.com/pourquoi-lia-va-fortement-influencer-le-recrutement-et-comment-vous-y-preparer/',
#  'https://www.mybeautifuljob.com/bts-nrc-lassurance-dun-avenir-professionnel/',
#  'https://www.mybeautifuljob.com/un-centre-de-formation-vous-aide-a-obtenir-un-bts-nrdc-en-alternance/',
#  'https://www.mybeautifuljob.com/les-secrets-dune-formation-en-negociation-reussie/',
#  'https://www.mybeautifuljob.com/quelle-est-la-finalite-dun-bilan-de-competences/',
#  'https://www.mybeautifuljob.com/campagne-sms-pourquoi-faire-de-la-segmentation/',
#  'https://www.mybeautifuljob.com/trouver-emploi-sur-linkedin/',
#  'https://www.mybeautifuljob.com/quels-sont-les-metiers-les-plus-recherches/',
#  'https://www.mybeautifuljob.com/quelles-sont-les-13-qualites-dun-manager-2/',
#  'https://www.mybeautifuljob.com/delai-de-prevenance-comment-le-calculer/',
#  'https://www.mybeautifuljob.com/le-salaire-moyen-en-france-en-2021/',
#  'https://www.mybeautifuljob.com/cours-de-maths-a-domicile-pourquoi-passer-par-aladom/',
#  'https://www.mybeautifuljob.com/bts-commerce-international-explication-salaires-et-debouchees/',
#  'https://www.mybeautifuljob.com/comment-se-mettre-a-son-compte-sans-diplome/',
#  'https://www.mybeautifuljob.com/developper-ses-competences-pour-acceder-a-de-nouvelles-opportunites-sur-le-marche-du-travail-a-strasbourg/',
#  'https://www.mybeautifuljob.com/lms-unice-astuces-pour-une-utilisation-optimale/',
#  'https://www.mybeautifuljob.com/ages-bts-quels-sont-les-membres-les-plus-jeunes/',
#  'https://www.mybeautifuljob.com/limportance-cruciale-dun-tableau-des-metres-cubes-pour-evaluer-vos-volumes/',
#  'https://www.mybeautifuljob.com/comprendre-le-prix-de-lessec-frais-de-scolarite-et-investissements/',
#  'https://www.mybeautifuljob.com/quels-sont-les-savoir-etre/',
#  'https://www.mybeautifuljob.com/que-savoir-sur-les-centres-de-formations-professionnelles/',
#  'https://www.mybeautifuljob.com/ou-trouver-les-meilleures-offres-de-formations/',
#  'https://www.mybeautifuljob.com/comment-organiser-une-formation-en-entreprise/',
#  'https://www.mybeautifuljob.com/comment-bien-choisir-une-formation/',
#  'https://www.mybeautifuljob.com/astuces-pour-trouver-un-etablissement-conduisant-a-un-emploi/',
#  'https://www.mybeautifuljob.com/combien-coute-un-bts-negociation-relation-client-nrc-en-2020/',
#  'https://www.mybeautifuljob.com/peut-on-devenir-autoentrepreneur-sans-diplome/',
#  'https://www.mybeautifuljob.com/pourquoi-sinscrire-dans-une-ecole-de-management/',
#  'https://www.mybeautifuljob.com/reconversion-professionnelle-quels-conseils-pour-changer-de-metier/',
#  'https://www.mybeautifuljob.com/consulter-des-articles-en-ligne-pour-se-former-en-periode-de-crise-sanitaire/',
#  'https://www.mybeautifuljob.com/comment-recompenser-les-meilleurs-salaries/',
#  'https://www.mybeautifuljob.com/comment-gerer-lhypercroissance-en-entreprise/',
#  'https://www.mybeautifuljob.com/comment-bien-recruter-dans-limmobilier/',
#  'https://www.mybeautifuljob.com/delai-de-prevenance-comment-le-calculer/',
#  'https://www.mybeautifuljob.com/le-salaire-moyen-en-france-en-2021/',
#  'https://www.mybeautifuljob.com/cours-de-maths-a-domicile-pourquoi-passer-par-aladom/',
#  'https://www.mybeautifuljob.com/bts-commerce-international-explication-salaires-et-debouchees/',
#  'https://www.mybeautifuljob.com/comment-se-mettre-a-son-compte-sans-diplome/',
#  'https://www.mybeautifuljob.com/developper-ses-competences-pour-acceder-a-de-nouvelles-opportunites-sur-le-marche-du-travail-a-strasbourg/',
#  'https://www.mybeautifuljob.com/lms-unice-astuces-pour-une-utilisation-optimale/',
#  'https://www.mybeautifuljob.com/ages-bts-quels-sont-les-membres-les-plus-jeunes/',
#  'https://www.mybeautifuljob.com/limportance-cruciale-dun-tableau-des-metres-cubes-pour-evaluer-vos-volumes/',
#  'https://www.mybeautifuljob.com/comprendre-le-prix-de-lessec-frais-de-scolarite-et-investissements/']

# %% [markdown]
# ### Récupérer les infos qu'on souhaite sur chaque article

# %%
def get_article_info(r, url_article):
    # Liste de variables
    noms_variables = [
        'url',  # URL scrapée
        'canonical_url', 'slug', 'meta_title', 'meta_desc',  # Infos issues de la balise meta
        'date_published', 'date_modified',  # Infos dates
        'author',  # Parfois en meta
        'title', 'category', 'views', 'reading_time',  # Metadonnées contenues ailleurs que dans la balise meta
        'content', 'raw_content'  # Contenu de la page
    ]
    
    # Initialisation du dictionnaire
    data = {nom: np.nan for nom in noms_variables}
    
    data['url'] = url_article
    
    soup = BeautifulSoup(r.content, 'lxml')
    
    try:
        data['canonical_url'] = soup.find('link', {'rel': 'canonical'})['href']
    except:
        pass
    
    try:
        data['slug'] = data['canonical_url'].split('/')[-2] if data['canonical_url'] else np.nan
    except:
        pass

    try:
        data['meta_title'] = soup.find('meta', {'property': 'og:title'})['content']
    except:
        pass

    try:
        data['meta_desc'] = soup.find('meta', {'property': 'og:description'})['content']
    except:
        pass

    try:
        data['date_published'] = pd.to_datetime(soup.find('meta', {'property': 'article:published_time'})['content'][:-6], utc=True)
    except:
        pass

    try:
        data['date_modified'] = pd.to_datetime(soup.find('meta', {'property': 'article:modified_time'})['content'][:-6], utc=True)
    except:
        pass

    try:
        data['author'] = soup.find("meta", {'name': 'author'})['content']
    except:
        try:
            data['author'] = soup.find(class_="author").text.split('Publié par ')[-1]
        except:
            pass

    try:
        data['title'] = soup.find('h1').text
    except:
        pass

    try:
        data['category'] = [x.text for x in soup.find_all(class_="tdb-entry-category")]
    except:
        pass

    try:
        data['views'] = int(soup.find('div', class_='views').text)
    except:
        pass

    try:
        data['reading_time'] = int(soup.find('meta', {'name': 'twitter:data2'})['content'].split(' ')[0]) if soup.find('meta', {'name': 'twitter:data2'}) and 'minutes' in soup.find('meta', {'name': 'twitter:data2'})['content'] else np.nan
    except:
        pass

    try:
        data['content'] = BeautifulSoup(str(soup.find("div", class_="td-post-content")), 'lxml').get_text()
    except:
        pass

    try:
        data['raw_content'] = str(soup.find("div", class_="td-post-content"))
    except:
        pass

    # Ajout de features
    data['length'] = len(str(data['content']).split())
    
    if pd.notnull(data['date_published']):
        data['days_since_published'] = int((pd.Timestamp.now(tz='UTC') - data['date_published']).days)
    else:
        data['days_since_published'] = np.nan
    
    # Création de la série
    series = pd.Series(data)
    series.name = url_article
    
    # Ajout de features supplémentaires
    if pd.notnull(data.get('views')) and pd.notnull(data.get('days_since_published')):
        series['views_daily'] = series['views'] / series['days_since_published']
        series['views_monthly'] = series['views_daily'] * 30
    else:
        series['views_daily'] = np.nan
        series['views_monthly'] = np.nan
    
    series['website'] = top_url
    
    return series

# %% [markdown]
# ## Fonction finale

# %%
article_list = get_articles_on_page(get_all_results_pages(get_max_page_results(top_search_url)))
# Out:
#   0%|          | 0/8 [00:00<?, ?it/s]

# %% [markdown]
# ### Fonction finale

# %%
# Import des packages
from concurrent.futures import ThreadPoolExecutor, as_completed
import time

# Initialisation du compteur
start_time = time.time()

# Fonction principale qui sauvegarde le DataFrame dans un fichier CSV et le retourne
def scrape_all_articles(urls, batch_size=250, max_workers=20):
    # Initialisation d'une session réutilisable
    session = rq.Session()

    # Création d'une fonction qui traite chaque URL
    def process_url(url):
            try:
                r = session.get(url)
                return get_article_info(r, url)
            except Exception as e:
                print(f"Erreur pour {url}: {str(e)}")
                return pd.Series(name=url)

    # Utilise ThreadPoolExecutor pour paralléliser le traitement
    results = []
    with ThreadPoolExecutor(max_workers=max_workers) as executor:
        # Parcourt la liste d'URLs par lots de taille 'batch_size'
        for i in range(0, len(urls), batch_size):
            # Extrait un lot d'URLs
            batch = urls[i:i+batch_size]
            # Crée et soumet des tâches pour chaque URL du lot
            futures = [executor.submit(process_url, url) for url in batch]
            
            # Traite les résultats au fur et à mesure qu'ils sont terminés
            for future in tqdm(as_completed(futures), total=len(batch), desc=f"Batch {i//batch_size + 1} / {len(urls)//batch_size+1}"):
                # Récupère le résultat de la tâche
                result = future.result()
                # Si le résultat n'est pas None (pas d'erreur), l'ajoute aux résultats
                if result is not None:
                    results.append(result)
    
    # Création du DataFrame final
    df_final = pd.DataFrame(results)
    
    # Ajout de colonnes calculées
    df_final['website'] = top_url
    df_final['scraping_date'] = pd.Timestamp.now(tz='UTC')

    df_final.columns = ['article_url', 'article_canonical_url', 'article_slug',
       'article_meta_title', 'article_meta_desc', 'article_date_published',
       'article_date_modified', 'article_author', 'article_title',
       'article_category', 'article_views', 'article_reading_time',
       'article_content', 'article_raw_content', 'article_length',
       'days_since_published', 'article_views_daily', 'article_views_monthly',
       'website', 'scraping_date']

    # Sauvegarde en CSV
    df_final.to_csv(f'scraping_{abbr}.csv', sep='|', index=True)
    print(f"Scraping terminé. Total d'articles : {len(df_final)}")
    return df_final

df = scrape_all_articles(article_list)

end_time = time.time()
print(end_time - start_time)
# Out:
# Batch 1 / 2:   0%|          | 0/250 [00:00<?, ?it/s]
# Batch 2 / 2:   0%|          | 0/194 [00:00<?, ?it/s]
# Scraping terminé. Total d'articles : 444
# 33.45772099494934

# %%
# Création d'un rapport de profil avec pandas_profiling
profile = ProfileReport(df, title=f"{abbr.title()} Scraping Report", explorative=True)

# Génération du rapport au format HTML
profile.to_file(f"scraping_report_{abbr}.html")
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# c:\Users\enzol\anaconda3\Lib\site-packages\ydata_profiling\model\correlations.py:66: UserWarning: There was an attempt to calculate the auto correlation, but this failed.
# To hide this warning, disable the calculation
# (using `df.profile_report(correlations={"auto": {"calculate": False}})`
# If this is problematic for your use case, please report this as an issue:
# https://github.com/ydataai/ydata-profiling/issues
# (include the error message: 'cannot reindex on an axis with duplicate labels')
#   warnings.warn(
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
